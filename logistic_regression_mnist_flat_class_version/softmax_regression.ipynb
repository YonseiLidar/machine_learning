# %%
# %matplotlib inline

# %%
from data_loading import mnist_flat_loader as mnist_flat
    
x_train, y_train, y_train_cls, x_test, y_test, y_test_cls, cls_names = mnist_flat.data_loading()

print(x_train.shape) 
print(y_train.shape) 
print(y_train_cls.shape) 
print(x_test.shape) 
print(y_test.shape) 
print(y_test_cls.shape)
# Out:
# (60000, 784)
# (60000, 10)
# (60000,)
# (10000, 784)
# (10000, 10)
# (10000,)

# %%
import numpy as np
import tensorflow as tf
from model.softmax_regression import SoftmaxRegression
from data_loading import mnist_flat_loader as mnist_flat
    
x_train, y_train, y_train_cls, x_test, y_test, y_test_cls, cls_names = mnist_flat.data_loading()
    
with tf.Session() as sess:
    a = SoftmaxRegression(x_train, y_train, y_train_cls, cls_names, sess,
                 lr=1e-4, epoch=100, batch_size=256, report_period=1000, np_seed=1, tf_seed=1,
                 initializer=tf.contrib.layers.variance_scaling_initializer(mode="FAN_AVG"),
                 save_path='result/model/model_1',
                 figure_save_dir='result/img')
    a.train()
        
    print('train accuracy : ', a.compute_accuracy(x_train, y_train, y_train_cls))
    print('test accuracy : ', a.compute_accuracy(x_test, y_test, y_test_cls))
    
with tf.Session() as sess:
    a = SoftmaxRegression(x_train, y_train, y_train_cls, cls_names, sess,
                 lr=1e-4, epoch=100, batch_size=256, report_period=1000, np_seed=1, tf_seed=1,
                 initializer=tf.contrib.layers.variance_scaling_initializer(mode="FAN_AVG"),
                 save_path='result/model/model_1',
                 figure_save_dir='result/img')
    a.restore()
        
    print('train accuracy : ', a.compute_accuracy(x_train, y_train, y_train_cls))
    print('test accuracy : ', a.compute_accuracy(x_test, y_test, y_test_cls))
    
    a.compute_confusion_matrix(x_test, y_test, y_test_cls)
    a.plot_9_images_with_false_prediction(x_test, y_test, y_test_cls)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0721 14:19:50.112889 4549449152 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0721 14:19:50.743098 4549449152 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/logistic_regression_mnist_flat/model/softmax_regression.py:91: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# W0721 14:19:50.743950 4549449152 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/logistic_regression_mnist_flat/model/softmax_regression.py:96: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0721 14:19:50.746775 4549449152 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/logistic_regression_mnist_flat/model/softmax_regression.py:100: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0721 14:19:50.781291 4549449152 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/logistic_regression_mnist_flat/model/softmax_regression.py:109: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0721 14:19:50.845552 4549449152 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/logistic_regression_mnist_flat/model/softmax_regression.py:186: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
# grandient_step :  1000
# loss :            0.7853299
# grandient_step :  2000
# loss :            0.6150547
# grandient_step :  3000
# loss :            0.3539853
# grandient_step :  4000
# loss :            0.36683697
# grandient_step :  5000
# loss :            0.35544658
# grandient_step :  6000
# loss :            0.34312588
# grandient_step :  7000
# loss :            0.3444804
# grandient_step :  8000
# loss :            0.36603895
# grandient_step :  9000
# loss :            0.27315992
# grandient_step :  10000
# loss :            0.30786532
# grandient_step :  11000
# loss :            0.27615327
# grandient_step :  12000
# loss :            0.19914378
# grandient_step :  13000
# loss :            0.3798272
# grandient_step :  14000
# loss :            0.24990322
# grandient_step :  15000
# loss :            0.3471185
# grandient_step :  16000
# loss :            0.18938245
# grandient_step :  17000
# loss :            0.28125554
# grandient_step :  18000
# loss :            0.23926505
# grandient_step :  19000
# loss :            0.2297267
# grandient_step :  20000
# loss :            0.2966473
# grandient_step :  21000
# loss :            0.3383023
# grandient_step :  22000
# loss :            0.20807023
# grandient_step :  23000
# loss :            0.26772016
# W0721 14:20:27.471410 4549449152 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/logistic_regression_mnist_flat/model/softmax_regression.py:170: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W0721 14:20:27.644295 4549449152 deprecation_wrapper.py:119] From /Users/sungchul/Dropbox/Git/machine_learning/logistic_regression_mnist_flat/model/softmax_regression.py:158: The name tf.train.import_meta_graph is deprecated. Please use tf.compat.v1.train.import_meta_graph instead.
#
# W0721 14:20:27.676639 4549449152 deprecation.py:323] From /Users/sungchul/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# train accuracy :  0.92705
# test accuracy :  0.9251
# train accuracy :  0.92705
# test accuracy :  0.9251
# [[ 961    0    2    2    0    5    6    2    2    0]
#  [   0 1114    3    2    0    1    4    2    9    0]
#  [   6    8  920   18   11    4   12   11   38    4]
#  [   3    1   20  921    0   24    2   12   19    8]
#  [   1    1    4    1  917    1   12    4    9   32]
#  [   8    2    3   30    8  779   17    5   33    7]
#  [  11    3    7    1    8   14  910    2    2    0]
#  [   1    5   22    8    6    0    0  949    2   35]
#  [   7    9    7   23    9   25    9   14  867    4]
#  [  11    7    1   10   29    7    0   25    6  913]]
