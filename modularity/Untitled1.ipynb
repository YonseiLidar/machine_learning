# %%
import tensorflow as tf
import numpy as np
tf.reset_default_graph()
tf.set_random_seed(0)
np.random.seed(0)

# %%
n_features = 3
X = tf.placeholder(tf.float32, shape=(None, n_features), name="X")

w1 = tf.Variable(tf.random_normal((n_features, 1)), name="weights1")
w2 = tf.Variable(tf.random_normal((n_features, 1)), name="weights2")
b1 = tf.Variable(0.0, name="bias1")
b2 = tf.Variable(0.0, name="bias2")

z1 = tf.add(tf.matmul(X, w1), b1, name="z1")
z2 = tf.add(tf.matmul(X, w2), b2, name="z2")

relu1 = tf.maximum(z1, 0., name="relu1")
relu2 = tf.maximum(z1, 0., name="relu2")  # Oops, cut&paste error! Did you spot it?

output = tf.add(relu1, relu2, name="output")

# %%
all_tensors = [tensor for op in tf.get_default_graph().get_operations() 
               for tensor in op.values()]
for tensor in all_tensors:
    print(tensor)
# Out:
# Tensor("X:0", shape=(?, 3), dtype=float32)
# Tensor("random_normal/shape:0", shape=(2,), dtype=int32)
# Tensor("random_normal/mean:0", shape=(), dtype=float32)
# Tensor("random_normal/stddev:0", shape=(), dtype=float32)
# Tensor("random_normal/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal/mul:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal:0", shape=(3, 1), dtype=float32)
# Tensor("weights1:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights1/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights1/read:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_1/shape:0", shape=(2,), dtype=int32)
# Tensor("random_normal_1/mean:0", shape=(), dtype=float32)
# Tensor("random_normal_1/stddev:0", shape=(), dtype=float32)
# Tensor("random_normal_1/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_1/mul:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_1:0", shape=(3, 1), dtype=float32)
# Tensor("weights2:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights2/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights2/read:0", shape=(3, 1), dtype=float32)
# Tensor("bias1/initial_value:0", shape=(), dtype=float32)
# Tensor("bias1:0", shape=(), dtype=float32_ref)
# Tensor("bias1/Assign:0", shape=(), dtype=float32_ref)
# Tensor("bias1/read:0", shape=(), dtype=float32)
# Tensor("bias2/initial_value:0", shape=(), dtype=float32)
# Tensor("bias2:0", shape=(), dtype=float32_ref)
# Tensor("bias2/Assign:0", shape=(), dtype=float32_ref)
# Tensor("bias2/read:0", shape=(), dtype=float32)
# Tensor("MatMul:0", shape=(?, 1), dtype=float32)
# Tensor("z1:0", shape=(?, 1), dtype=float32)
# Tensor("MatMul_1:0", shape=(?, 1), dtype=float32)
# Tensor("z2:0", shape=(?, 1), dtype=float32)
# Tensor("relu1/y:0", shape=(), dtype=float32)
# Tensor("relu1:0", shape=(?, 1), dtype=float32)
# Tensor("relu2/y:0", shape=(), dtype=float32)
# Tensor("relu2:0", shape=(?, 1), dtype=float32)
# Tensor("output:0", shape=(?, 1), dtype=float32)

# %%
import tensorflow as tf
import numpy as np
tf.reset_default_graph()
tf.set_random_seed(0)
np.random.seed(0)

# %%
def relu(X):
    w_shape = (int(X.get_shape()[1]), 1)
    w = tf.Variable(tf.random_normal(w_shape), name="weights")
    b = tf.Variable(0.0, name="bias")
    z = tf.add(tf.matmul(X, w), b, name="z")
    return tf.maximum(z, 0., name="relu")

n_features = 3
X = tf.placeholder(tf.float32, shape=(None, n_features), name="X")
relus = [relu(X) for i in range(5)]
output = tf.add_n(relus, name="output")

# %%
all_tensors = [tensor for op in tf.get_default_graph().get_operations() 
               for tensor in op.values()]
for tensor in all_tensors:
    print(tensor)
# Out:
# Tensor("X:0", shape=(?, 3), dtype=float32)
# Tensor("random_normal/shape:0", shape=(2,), dtype=int32)
# Tensor("random_normal/mean:0", shape=(), dtype=float32)
# Tensor("random_normal/stddev:0", shape=(), dtype=float32)
# Tensor("random_normal/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal/mul:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal:0", shape=(3, 1), dtype=float32)
# Tensor("weights:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights/read:0", shape=(3, 1), dtype=float32)
# Tensor("bias/initial_value:0", shape=(), dtype=float32)
# Tensor("bias:0", shape=(), dtype=float32_ref)
# Tensor("bias/Assign:0", shape=(), dtype=float32_ref)
# Tensor("bias/read:0", shape=(), dtype=float32)
# Tensor("MatMul:0", shape=(?, 1), dtype=float32)
# Tensor("z:0", shape=(?, 1), dtype=float32)
# Tensor("relu/y:0", shape=(), dtype=float32)
# Tensor("relu:0", shape=(?, 1), dtype=float32)
# Tensor("random_normal_1/shape:0", shape=(2,), dtype=int32)
# Tensor("random_normal_1/mean:0", shape=(), dtype=float32)
# Tensor("random_normal_1/stddev:0", shape=(), dtype=float32)
# Tensor("random_normal_1/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_1/mul:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_1:0", shape=(3, 1), dtype=float32)
# Tensor("weights_1:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_1/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_1/read:0", shape=(3, 1), dtype=float32)
# Tensor("bias_1/initial_value:0", shape=(), dtype=float32)
# Tensor("bias_1:0", shape=(), dtype=float32_ref)
# Tensor("bias_1/Assign:0", shape=(), dtype=float32_ref)
# Tensor("bias_1/read:0", shape=(), dtype=float32)
# Tensor("MatMul_1:0", shape=(?, 1), dtype=float32)
# Tensor("z_1:0", shape=(?, 1), dtype=float32)
# Tensor("relu_1/y:0", shape=(), dtype=float32)
# Tensor("relu_1:0", shape=(?, 1), dtype=float32)
# Tensor("random_normal_2/shape:0", shape=(2,), dtype=int32)
# Tensor("random_normal_2/mean:0", shape=(), dtype=float32)
# Tensor("random_normal_2/stddev:0", shape=(), dtype=float32)
# Tensor("random_normal_2/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_2/mul:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_2:0", shape=(3, 1), dtype=float32)
# Tensor("weights_2:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_2/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_2/read:0", shape=(3, 1), dtype=float32)
# Tensor("bias_2/initial_value:0", shape=(), dtype=float32)
# Tensor("bias_2:0", shape=(), dtype=float32_ref)
# Tensor("bias_2/Assign:0", shape=(), dtype=float32_ref)
# Tensor("bias_2/read:0", shape=(), dtype=float32)
# Tensor("MatMul_2:0", shape=(?, 1), dtype=float32)
# Tensor("z_2:0", shape=(?, 1), dtype=float32)
# Tensor("relu_2/y:0", shape=(), dtype=float32)
# Tensor("relu_2:0", shape=(?, 1), dtype=float32)
# Tensor("random_normal_3/shape:0", shape=(2,), dtype=int32)
# Tensor("random_normal_3/mean:0", shape=(), dtype=float32)
# Tensor("random_normal_3/stddev:0", shape=(), dtype=float32)
# Tensor("random_normal_3/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_3/mul:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_3:0", shape=(3, 1), dtype=float32)
# Tensor("weights_3:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_3/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_3/read:0", shape=(3, 1), dtype=float32)
# Tensor("bias_3/initial_value:0", shape=(), dtype=float32)
# Tensor("bias_3:0", shape=(), dtype=float32_ref)
# Tensor("bias_3/Assign:0", shape=(), dtype=float32_ref)
# Tensor("bias_3/read:0", shape=(), dtype=float32)
# Tensor("MatMul_3:0", shape=(?, 1), dtype=float32)
# Tensor("z_3:0", shape=(?, 1), dtype=float32)
# Tensor("relu_3/y:0", shape=(), dtype=float32)
# Tensor("relu_3:0", shape=(?, 1), dtype=float32)
# Tensor("random_normal_4/shape:0", shape=(2,), dtype=int32)
# Tensor("random_normal_4/mean:0", shape=(), dtype=float32)
# Tensor("random_normal_4/stddev:0", shape=(), dtype=float32)
# Tensor("random_normal_4/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_4/mul:0", shape=(3, 1), dtype=float32)
# Tensor("random_normal_4:0", shape=(3, 1), dtype=float32)
# Tensor("weights_4:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_4/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("weights_4/read:0", shape=(3, 1), dtype=float32)
# Tensor("bias_4/initial_value:0", shape=(), dtype=float32)
# Tensor("bias_4:0", shape=(), dtype=float32_ref)
# Tensor("bias_4/Assign:0", shape=(), dtype=float32_ref)
# Tensor("bias_4/read:0", shape=(), dtype=float32)
# Tensor("MatMul_4:0", shape=(?, 1), dtype=float32)
# Tensor("z_4:0", shape=(?, 1), dtype=float32)
# Tensor("relu_4/y:0", shape=(), dtype=float32)
# Tensor("relu_4:0", shape=(?, 1), dtype=float32)
# Tensor("output:0", shape=(?, 1), dtype=float32)

# %%
import tensorflow as tf
import numpy as np
tf.reset_default_graph()
tf.set_random_seed(0)
np.random.seed(0)

# %%
def relu(X):
    with tf.variable_scope("relu"):
        w_shape = (int(X.get_shape()[1]), 1)                         
        w = tf.Variable(tf.random_normal(w_shape), name="weights")   
        b = tf.Variable(0.0, name="bias")                            
        z = tf.add(tf.matmul(X, w), b, name="z")                     
        return tf.maximum(z, 0., name="max")                         
    
n_features = 3
X = tf.placeholder(tf.float32, shape=(None, n_features), name="X")
relus = [relu(X) for i in range(5)]
output = tf.add_n(relus, name="output")

# %%
all_tensors = [tensor for op in tf.get_default_graph().get_operations() 
               for tensor in op.values()]
for tensor in all_tensors:
    print(tensor)
# Out:
# Tensor("X:0", shape=(?, 3), dtype=float32)
# Tensor("relu/random_normal/shape:0", shape=(2,), dtype=int32)
# Tensor("relu/random_normal/mean:0", shape=(), dtype=float32)
# Tensor("relu/random_normal/stddev:0", shape=(), dtype=float32)
# Tensor("relu/random_normal/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("relu/random_normal/mul:0", shape=(3, 1), dtype=float32)
# Tensor("relu/random_normal:0", shape=(3, 1), dtype=float32)
# Tensor("relu/weights:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu/weights/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu/weights/read:0", shape=(3, 1), dtype=float32)
# Tensor("relu/bias/initial_value:0", shape=(), dtype=float32)
# Tensor("relu/bias:0", shape=(), dtype=float32_ref)
# Tensor("relu/bias/Assign:0", shape=(), dtype=float32_ref)
# Tensor("relu/bias/read:0", shape=(), dtype=float32)
# Tensor("relu/MatMul:0", shape=(?, 1), dtype=float32)
# Tensor("relu/z:0", shape=(?, 1), dtype=float32)
# Tensor("relu/max/y:0", shape=(), dtype=float32)
# Tensor("relu/max:0", shape=(?, 1), dtype=float32)
# Tensor("relu_1/random_normal/shape:0", shape=(2,), dtype=int32)
# Tensor("relu_1/random_normal/mean:0", shape=(), dtype=float32)
# Tensor("relu_1/random_normal/stddev:0", shape=(), dtype=float32)
# Tensor("relu_1/random_normal/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_1/random_normal/mul:0", shape=(3, 1), dtype=float32)
# Tensor("relu_1/random_normal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_1/weights:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_1/weights/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_1/weights/read:0", shape=(3, 1), dtype=float32)
# Tensor("relu_1/bias/initial_value:0", shape=(), dtype=float32)
# Tensor("relu_1/bias:0", shape=(), dtype=float32_ref)
# Tensor("relu_1/bias/Assign:0", shape=(), dtype=float32_ref)
# Tensor("relu_1/bias/read:0", shape=(), dtype=float32)
# Tensor("relu_1/MatMul:0", shape=(?, 1), dtype=float32)
# Tensor("relu_1/z:0", shape=(?, 1), dtype=float32)
# Tensor("relu_1/max/y:0", shape=(), dtype=float32)
# Tensor("relu_1/max:0", shape=(?, 1), dtype=float32)
# Tensor("relu_2/random_normal/shape:0", shape=(2,), dtype=int32)
# Tensor("relu_2/random_normal/mean:0", shape=(), dtype=float32)
# Tensor("relu_2/random_normal/stddev:0", shape=(), dtype=float32)
# Tensor("relu_2/random_normal/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_2/random_normal/mul:0", shape=(3, 1), dtype=float32)
# Tensor("relu_2/random_normal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_2/weights:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_2/weights/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_2/weights/read:0", shape=(3, 1), dtype=float32)
# Tensor("relu_2/bias/initial_value:0", shape=(), dtype=float32)
# Tensor("relu_2/bias:0", shape=(), dtype=float32_ref)
# Tensor("relu_2/bias/Assign:0", shape=(), dtype=float32_ref)
# Tensor("relu_2/bias/read:0", shape=(), dtype=float32)
# Tensor("relu_2/MatMul:0", shape=(?, 1), dtype=float32)
# Tensor("relu_2/z:0", shape=(?, 1), dtype=float32)
# Tensor("relu_2/max/y:0", shape=(), dtype=float32)
# Tensor("relu_2/max:0", shape=(?, 1), dtype=float32)
# Tensor("relu_3/random_normal/shape:0", shape=(2,), dtype=int32)
# Tensor("relu_3/random_normal/mean:0", shape=(), dtype=float32)
# Tensor("relu_3/random_normal/stddev:0", shape=(), dtype=float32)
# Tensor("relu_3/random_normal/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_3/random_normal/mul:0", shape=(3, 1), dtype=float32)
# Tensor("relu_3/random_normal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_3/weights:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_3/weights/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_3/weights/read:0", shape=(3, 1), dtype=float32)
# Tensor("relu_3/bias/initial_value:0", shape=(), dtype=float32)
# Tensor("relu_3/bias:0", shape=(), dtype=float32_ref)
# Tensor("relu_3/bias/Assign:0", shape=(), dtype=float32_ref)
# Tensor("relu_3/bias/read:0", shape=(), dtype=float32)
# Tensor("relu_3/MatMul:0", shape=(?, 1), dtype=float32)
# Tensor("relu_3/z:0", shape=(?, 1), dtype=float32)
# Tensor("relu_3/max/y:0", shape=(), dtype=float32)
# Tensor("relu_3/max:0", shape=(?, 1), dtype=float32)
# Tensor("relu_4/random_normal/shape:0", shape=(2,), dtype=int32)
# Tensor("relu_4/random_normal/mean:0", shape=(), dtype=float32)
# Tensor("relu_4/random_normal/stddev:0", shape=(), dtype=float32)
# Tensor("relu_4/random_normal/RandomStandardNormal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_4/random_normal/mul:0", shape=(3, 1), dtype=float32)
# Tensor("relu_4/random_normal:0", shape=(3, 1), dtype=float32)
# Tensor("relu_4/weights:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_4/weights/Assign:0", shape=(3, 1), dtype=float32_ref)
# Tensor("relu_4/weights/read:0", shape=(3, 1), dtype=float32)
# Tensor("relu_4/bias/initial_value:0", shape=(), dtype=float32)
# Tensor("relu_4/bias:0", shape=(), dtype=float32_ref)
# Tensor("relu_4/bias/Assign:0", shape=(), dtype=float32_ref)
# Tensor("relu_4/bias/read:0", shape=(), dtype=float32)
# Tensor("relu_4/MatMul:0", shape=(?, 1), dtype=float32)
# Tensor("relu_4/z:0", shape=(?, 1), dtype=float32)
# Tensor("relu_4/max/y:0", shape=(), dtype=float32)
# Tensor("relu_4/max:0", shape=(?, 1), dtype=float32)
# Tensor("output:0", shape=(?, 1), dtype=float32)
